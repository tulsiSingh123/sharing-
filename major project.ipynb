# %%
from arcgis.gis import GIS
gis = GIS("https://upesproject.maps.arcgis.com/home/webmap/viewer.html","tulsiSingh","tulsiSingh@123")
crime = gis.content.search('title: crime uk')[0]
crime
# Out:
# <Item title:"crime uk" type:Feature Layer Collection owner:tulsiSingh>

# %%
# Adding Basemap
map =gis.map('Uttarakhand')
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-48af7de1-709d-4a97-85f1-a0f908320c5d"><img src=""></img></div>

# %%
sat=crime.layers[0]
sat
# Out:
# <FeatureLayer url:"https://services5.arcgis.com/w0soXgeeIu6NJ96D/arcgis/rest/services/crime_uk/FeatureServer/0">

# %%
map.add_layer(sat)
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-48af7de1-709d-4a97-85f1-a0f908320c5d"><img src=""></img></div>

# %%
query_result = crime.layers[0].query( out_fields = "*",returnGeometry = True)
query_result
print(len(query_result))
# Out:
# 167

# %%
att_data_frame = query_result.sdf
att_data_frame
# Out:
# F:\miniconda\lib\site-packages\IPython\lib\pretty.py:402: FutureWarning: 'ExtensionArray._formatting_values' is deprecated. Specify 'ExtensionArray._formatter' instead.
#   return _repr_pprint(obj, self, cycle)
# F:\miniconda\lib\site-packages\pandas\io\formats\html.py:606: FutureWarning: 'ExtensionArray._formatting_values' is deprecated. Specify 'ExtensionArray._formatter' instead.
#   super().render()
#         STATE_UT          DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0    UTTARAKHAND     TEHRI GARHWAL  2009       0                  2
# 1    UTTARAKHAND  UDHAMSINGH NAGAR  2009      50                 49
# 2    UTTARAKHAND        UTTARKASHI  2009       1                  0
# 3    UTTARAKHAND            ALMORA  2010       3                  3
# 4    UTTARAKHAND         BAGESHWAR  2010       2                  0
# ..           ...               ...   ...     ...                ...
# 162  UTTARAKHAND         BAGESHWAR  2005      10                  5
# ...

# %%
crime1 = gis.content.search('title: layer1')[0]
crime1
# Out:
# <Item title:"layer1" type:Feature Layer Collection owner:tulsiSingh>

# %%
crime2 = gis.content.search('title:layer2')[0]
crime2
# Out:
# <Item title:"layer2" type:Feature Layer Collection owner:tulsiSingh>

# %%
crime3 = gis.content.search('title:layer3')[0]
crime3
# Out:
# <Item title:"layer3" type:Feature Layer Collection owner:tulsiSingh>

# %%
crime4 = gis.content.search('title:layer4')[0]
crime4
# Out:
# <Item title:"layer4" type:Feature Layer Collection owner:tulsiSingh>

# %%
crime5 = gis.content.search('title:layer5')[0]
crime5
# Out:
# <Item title:"layer5" type:Feature Layer Collection owner:tulsiSingh>

# %%
crime6 = gis.content.search('title:layer6')[0]
crime6
# Out:
# <Item title:"layer6" type:Feature Layer Collection owner:tulsiSingh>

# %%
run=crime1.layers[0]
run
# Out:
# <FeatureLayer url:"https://services5.arcgis.com/w0soXgeeIu6NJ96D/arcgis/rest/services/layer1/FeatureServer/0">

# %%
run2=crime2.layers[0]
run2
# Out:
# <FeatureLayer url:"https://services5.arcgis.com/w0soXgeeIu6NJ96D/arcgis/rest/services/layer2/FeatureServer/0">

# %%
run3=crime3.layers[0]
run3
# Out:
# <FeatureLayer url:"https://services5.arcgis.com/w0soXgeeIu6NJ96D/arcgis/rest/services/layer3/FeatureServer/0">

# %%
run4=crime4.layers[0]
run4
# Out:
# <FeatureLayer url:"https://services5.arcgis.com/w0soXgeeIu6NJ96D/arcgis/rest/services/layer4/FeatureServer/0">

# %%
run5= crime5.layers[0]
run5
# Out:
# <FeatureLayer url:"https://services5.arcgis.com/w0soXgeeIu6NJ96D/arcgis/rest/services/layer5/FeatureServer/0">

# %%
run6=crime6.layers[0]
run6
# Out:
# <FeatureLayer url:"https://services5.arcgis.com/w0soXgeeIu6NJ96D/arcgis/rest/services/layer6/FeatureServer/0">

# %%
map.add_layer(run)
map
map.add_layer(run2)
map
map.add_layer(run3)
map
map.add_layer(run4)
map
map.add_layer(run5)
map
map.add_layer(run6)
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-48af7de1-709d-4a97-85f1-a0f908320c5d"><img src=""></img></div>

# %%
query_result = crime1.layers[0].query( out_fields = "*",returnGeometry = True)
query_result
print(len(query_result))
# Out:
# 24

# %%
att_data_frame = query_result.sdf
att_data_frame
# Out:
#        STATE_UT          DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0   UTTARAKHAND         BAGESHWAR  2001      10                  7
# 1   UTTARAKHAND           CHAMOLI  2001      13                  6
# 2   UTTARAKHAND         CHAMPAWAT  2001       3                  3
# 3   UTTARAKHAND          DEHRADUN  2001      32                 66
# 4   UTTARAKHAND          HARIDWAR  2001      94                 75
# 5   UTTARAKHAND          NAINITAL  2001      36                 31
# 6   UTTARAKHAND     PAURI GARHWAL  2001      26                  9
# 7   UTTARAKHAND       PITHORAGARH  2001       8                  3
# 8   UTTARAKHAND      RUDRA PRAYAG  2001       5                  2
# 9   UTTARAKHAND     TEHRI GARHWAL  2001       7                 10
# 10  UTTARAKHAND  UDHAMSINGH NAGAR  2001      54                 44
# 11  UTTARAKHAND        UTTARKASHI  2001      10                 11
# 12  UTTARAKHAND            ALMORA  2002      17                 14
# ...

# %%
query_result = crime2.layers[0].query( out_fields = "*",returnGeometry = True)
query_result
print(len(query_result))
# Out:
# 25

# %%
att_data_frame = query_result.sdf
att_data_frame
# Out:
#        STATE_UT          DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0   UTTARAKHAND            ALMORA  2003      15                  5
# 1   UTTARAKHAND         BAGESHWAR  2003      11                  4
# 2   UTTARAKHAND           CHAMOLI  2003       9                  9
# 3   UTTARAKHAND         CHAMPAWAT  2003       7                  6
# 4   UTTARAKHAND          DEHRADUN  2003      31                 43
# 5   UTTARAKHAND          HARIDWAR  2003      75                 45
# 6   UTTARAKHAND          NAINITAL  2003      31                 30
# 7   UTTARAKHAND     PAURI GARHWAL  2003      15                 15
# 8   UTTARAKHAND       PITHORAGARH  2003       5                  9
# 9   UTTARAKHAND      RUDRA PRAYAG  2003       8                  4
# 10  UTTARAKHAND     TEHRI GARHWAL  2003       9                 23
# 11  UTTARAKHAND  UDHAMSINGH NAGAR  2003      46                 41
# 12  UTTARAKHAND        UTTARKASHI  2003       6                  2
# ...

# %%
query_result = crime3.layers[0].query( out_fields = "*",returnGeometry = True)
query_result
print(len(query_result))
# Out:
# 26

# %%
att_data_frame = query_result.sdf
att_data_frame
# Out:
#        STATE_UT          DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0   UTTARAKHAND            ALMORA  2005      22                  7
# 1   UTTARAKHAND         BAGESHWAR  2005      10                  5
# 2   UTTARAKHAND           CHAMOLI  2005       9                  4
# 3   UTTARAKHAND         CHAMPAWAT  2005       7                  0
# 4   UTTARAKHAND          DEHRADUN  2005      42                 39
# 5   UTTARAKHAND          HARIDWAR  2005      65                 56
# 6   UTTARAKHAND          NAINITAL  2005      31                 29
# 7   UTTARAKHAND     PAURI GARHWAL  2005      17                  6
# 8   UTTARAKHAND       PITHORAGARH  2005       8                  4
# 9   UTTARAKHAND      RUDRA PRAYAG  2005      11                  4
# 10  UTTARAKHAND     TEHRI GARHWAL  2005      11                 10
# 11  UTTARAKHAND  UDHAMSINGH NAGAR  2005      40                 34
# 12  UTTARAKHAND        UTTARKASHI  2005       6                  4
# ...

# %%
query_result = crime4.layers[0].query( out_fields = "*",returnGeometry = True)
query_result
print(len(query_result))
# Out:
# 26

# %%
att_data_frame = query_result.sdf
att_data_frame
# Out:
#        STATE_UT          DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0   UTTARAKHAND            ALMORA  2007      19                  9
# 1   UTTARAKHAND         BAGESHWAR  2007      10                  1
# 2   UTTARAKHAND           CHAMOLI  2007      15                  9
# 3   UTTARAKHAND         CHAMPAWAT  2007       5                  0
# 4   UTTARAKHAND          DEHRADUN  2007      37                 50
# 5   UTTARAKHAND          HARIDWAR  2007      55                 59
# 6   UTTARAKHAND          NAINITAL  2007      26                 19
# 7   UTTARAKHAND     PAURI GARHWAL  2007      19                  7
# 8   UTTARAKHAND       PITHORAGARH  2007       9                  2
# 9   UTTARAKHAND      RUDRA PRAYAG  2007       6                  6
# 10  UTTARAKHAND     TEHRI GARHWAL  2007      11                  7
# 11  UTTARAKHAND  UDHAMSINGH NAGAR  2007      54                 56
# 12  UTTARAKHAND        UTTARKASHI  2007       2                  3
# ...

# %%
query_result = crime5.layers[0].query( out_fields = "*",returnGeometry = True)
query_result
print(len(query_result))
# Out:
# 26

# %%
att_data_frame = query_result.sdf
att_data_frame
# Out:
#        STATE_UT          DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0   UTTARAKHAND            ALMORA  2009       9                  3
# 1   UTTARAKHAND         BAGESHWAR  2009       3                  0
# 2   UTTARAKHAND           CHAMOLI  2009       3                  1
# 3   UTTARAKHAND         CHAMPAWAT  2009       4                  5
# 4   UTTARAKHAND          DEHRADUN  2009      24                 41
# 5   UTTARAKHAND          HARIDWAR  2009      67                 58
# 6   UTTARAKHAND          NAINITAL  2009      24                 20
# 7   UTTARAKHAND     PAURI GARHWAL  2009       8                  3
# 8   UTTARAKHAND       PITHORAGARH  2009       2                  3
# 9   UTTARAKHAND      RUDRA PRAYAG  2009       0                  0
# 10  UTTARAKHAND     TEHRI GARHWAL  2009       0                  2
# 11  UTTARAKHAND  UDHAMSINGH NAGAR  2009      50                 49
# 12  UTTARAKHAND        UTTARKASHI  2009       1                  0
# ...

# %%
query_result = crime6.layers[0].query( out_fields = "*",returnGeometry = True)
query_result
print(len(query_result))
# Out:
# 26

# %%
att_data_frame = query_result.sdf
att_data_frame
# Out:
#        STATE_UT          DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0   UTTARAKHAND            ALMORA  2011       2                  0
# 1   UTTARAKHAND         BAGESHWAR  2011       1                  0
# 2   UTTARAKHAND           CHAMOLI  2011       4                  2
# 3   UTTARAKHAND         CHAMPAWAT  2011       2                  6
# 4   UTTARAKHAND          DEHRADUN  2011      25                 35
# 5   UTTARAKHAND          HARIDWAR  2011      56                 58
# 6   UTTARAKHAND          NAINITAL  2011      17                 14
# 7   UTTARAKHAND     PAURI GARHWAL  2011       6                  1
# 8   UTTARAKHAND       PITHORAGARH  2011       5                  3
# 9   UTTARAKHAND      RUDRA PRAYAG  2011       5                  3
# 10  UTTARAKHAND     TEHRI GARHWAL  2011       4                  1
# 11  UTTARAKHAND  UDHAMSINGH NAGAR  2011      49                 65
# 12  UTTARAKHAND        UTTARKASHI  2011       2                  1
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
query_result = crime1.layers.query(where = 'ATTEMPT_TO_MURDER' > 10 and 'RAPE' > 7 , out_fields ="*", returnGeometry =True)
query_result
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-2fc2b412b49c> in <module>
# ----> 1 query_result = crime1.layers.query(where = 'ATTEMPT_TO_MURDER' > 10 and 'RAPE' > 7 , out_fields ="*", returnGeometry =True)
#       2 query_result
#
# AttributeError: 'list' object has no attribute 'query'
